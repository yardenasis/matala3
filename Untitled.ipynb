# %%
file=open("WhatsApp.txt",encoding='utf8')
def BD_WHATSAPP (file):
    import json
    lst = []
    dictionary = dict()
    dict_id = 0
    for line in file:
            flag = None
            try:
                if ("הוסיף/ה" in line or "<נכללה" in line
                        or "מקצה-לקצה" in line or "נוצרה" in line):
                    continue
                notice = dict()
                index_date = line.index('-')
                date = line[0: index_date]
                num_phone = line[ index_date + 1:line.index(':',  index_date)]
                text = line[line.index(':',  index_date) + 1:]
                for key, value in dictionary.items():
                    if value ==  num_phone:
                        flag = key
                if flag is not None:
                    phone = flag
                else:
                    dictionary[dict_id] = num_phone
                    num_phone= dict_id
                    dict_id += 1
                notice['datetime'] = date
                notice['id'] =  num_phone
                notice['text'] = text
                lst.append(notice)
            except:
                lst[-1]['text'] += line
    
    
    file=open("WhatsApp.txt",encoding='utf8')       
    for line in file:
        try:
            if not  "נוצרה"  in line:
                continue
            
            metadata = dict()
            chatname_place = line.split('"')
            chatname=chatname_place[1]
            metadata["chat_name"] = chatname
            creationdate = line.split('-')
            metadata["creation_date"]=creationdate[0]
            creator = line.split()
            metadata["creator"]=line[65:81]
        except:
            continue
    all_information = dict()
    all_information["notice"] = lst 
    
    all_information["metadata"] = metadata
    BD_json = chatname+".txt"
    outputfile = open(BD_json , 'w', encoding='utf8')
    outputfile.write(json.dumps(all_information, indent=4, ensure_ascii=False))
    outputfile.close()
    
    return(all_information)

BD_WHATSAPP(file)
# Out:
# {'notice': [{'datetime': '6.4.2021, 11:40 ',
#    'id': 0,
#    'text': ' <המדיה לא נכללה>\n'},
#   {'datetime': '6.4.2021, 11:58 ', 'id': 1, 'text': ' ליה תגיע😍\n'},
#   {'datetime': '6.4.2021, 12:09 ', 'id': 2, 'text': ' מזל טוב, אמה תגיע\n'},
#   {'datetime': '6.4.2021, 12:09 ',
#    'id': ' \u200f\u202a+972 50-255-8663\u202c\u200f',
#    'text': ' תודה❤️❤️\n'},
#   {'datetime': '6.4.2021, 12:23 ',
#    'id': 3,
#    'text': ' אשמח לפרטים.  לא ראיתי את ההזמנה😊\n'},
#   {'datetime': '6.4.2021, 12:30 ',
#    'id': 4,
#    'text': ' המון מזל טוב ♥️♥️♥️\nלין תגיע בע"ה\n'},
#   {'datetime': '6.4.2021, 12:30 ',
#    'id': ' \u200f\u202a+972 50-255-8663\u202c\u200f',
#    'text': " יום הולדת בנות ב 28.4 בשעה 17:00- 19:00 רח' הנביאים 30 קומה שלישית דירה 12\n"},
#   {'datetime': '6.4.2021, 12:30 ',
#    'id': ' \u200f\u202a+972 50-255-8663\u202c\u200f',
#    'text': ' 🥰\n'},
#   {'datetime': '6.4.2021, 14:20 ', 'id': 5, 'text': ' מזל טוב 🎉🎉🎈🎈נטע תגיע\n'},
#   {'datetime': '6.4.2021, 14:25 ', 'id': 6, 'text': ' מזל טוב עלמה תגיע💓\n'},
#   {'datetime': '6.4.2021, 14:31 ',
#    'id': ' \u200f\u202a+972 50-255-8663\u202c\u200f',
#    'text': ' 👍🏻🥰🥰\n'},
#   {'datetime': '6.4.2021, 14:32 ',
#    'id': 7,
#    'text': ' מזל טוב🎈🎈🎈\nרומי תגיע\n'},
#   {'datetime': '6.4.2021, 14:33 ',
#    'id': 8,
#    'text': ' אוריין תגיע בשמחה מזל טוב\n'},
#   {'datetime': '6.4.2021, 14:45 ',
#    'id': ' \u200f\u202a+972 50-255-8663\u202c\u200f',
#    'text': ' 👍🏻🥰\n'},
#   {'datetime': '6.4.2021, 14:52 ',
#    'id': ' יעל קורנפלד',
#    'text': ' ארבל תגיע בשמחה 🎈\n'},
#   {'datetime': '6.4.2021, 15:17 ', 'id': 9, 'text': ' נטע תגיע בשמחה\n'},
#   {'datetime': '6.4.2021, 15:26 ',
#    'id': ' \u200f\u202a+972 50-255-8663\u202c\u200f',
#    'text': ' 👍🏻🤗\n'},
#   {'datetime': '6.4.2021, 17:14 ',
#    'id': 10,
#    'text': ' מזל טוב🎊🎉\nרומי תגיע\n'},
#   {'datetime': '6.4.2021, 17:48 ', 'id': 11, 'text': ' גאיה תגיע בשמחה🎂\n'},
#   {'datetime': '6.4.2021, 17:59 ',
#    'id': ' \u200f\u202a+972 50-255-8663\u202c\u200f',
#    'text': ' תודה🤗\n'},
#   {'datetime': '7.4.2021, 11:56 ', 'id': 12, 'text': ' מיה בן שואן תגיע 😁\n'},
#   {'datetime': '7.4.2021, 12:24 ',
#    'id': ' \u200f\u202a+972 50-255-8663\u202c\u200f',
#    'text': ' 👍🏻🤗\n'}],
#  'metadata': {'chat_name': "יום הולדת בנות לנוי'ה",
#   'creation_date': '6.4.2021, 11:39 ',
#   'creator': '+972 50-255-8663'}}
